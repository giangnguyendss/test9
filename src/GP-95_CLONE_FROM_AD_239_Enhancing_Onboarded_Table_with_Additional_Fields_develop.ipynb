# %%
# %sql
-- Databricks SQL script: Add and validate new fields in patient_data table, display output
-- Purpose: Ensure new fields are present, validate their values, and display the updated patient_data table
-- Author: Giang Nguyen
-- Date: 2025-10-13
-- Description: This script validates the existence and correctness of the newly added fields in purgo_playground.patient_data, applies data quality checks, and displays the final table for downstream processing and reporting.

USE CATALOG purgo_databricks;

-- Validate that all required columns exist in patient_data with correct types and nullability

WITH required_columns AS (
  SELECT 'patient_id' AS column_name, 'bigint' AS data_type, 'YES' AS is_nullable
  UNION ALL SELECT 'patient_name', 'string', 'YES'
  UNION ALL SELECT 'age', 'bigint', 'YES'
  UNION ALL SELECT 'diagnosis', 'string', 'YES'
  UNION ALL SELECT 'treatment', 'string', 'YES'
  UNION ALL SELECT 'ingestion_date', 'timestamp', 'YES'
  UNION ALL SELECT 'source_system', 'string', 'YES'
  UNION ALL SELECT 'record_status', 'string', 'YES'
  UNION ALL SELECT 'created_by', 'string', 'YES'
  UNION ALL SELECT 'modified_by', 'string', 'YES'
),
actual_columns AS (
  SELECT
    column_name,
    data_type,
    is_nullable
  FROM information_schema.columns
  WHERE table_catalog = 'purgo_databricks'
    AND table_schema = 'purgo_playground'
    AND table_name = 'patient_data'
)

SELECT COUNT(*) AS missing_columns
FROM required_columns rc
LEFT JOIN actual_columns ac
  ON rc.column_name = ac.column_name
  AND rc.data_type = ac.data_type
  AND rc.is_nullable = ac.is_nullable
WHERE ac.column_name IS NULL;

-- Validate allowed values for record_status

WITH required_columns AS (
  SELECT 'patient_id' AS column_name, 'bigint' AS data_type, 'YES' AS is_nullable
  UNION ALL SELECT 'patient_name', 'string', 'YES'
  UNION ALL SELECT 'age', 'bigint', 'YES'
  UNION ALL SELECT 'diagnosis', 'string', 'YES'
  UNION ALL SELECT 'treatment', 'string', 'YES'
  UNION ALL SELECT 'ingestion_date', 'timestamp', 'YES'
  UNION ALL SELECT 'source_system', 'string', 'YES'
  UNION ALL SELECT 'record_status', 'string', 'YES'
  UNION ALL SELECT 'created_by', 'string', 'YES'
  UNION ALL SELECT 'modified_by', 'string', 'YES'
),
actual_columns AS (
  SELECT
    column_name,
    data_type,
    is_nullable
  FROM information_schema.columns
  WHERE table_catalog = 'purgo_databricks'
    AND table_schema = 'purgo_playground'
    AND table_name = 'patient_data'
)

SELECT COUNT(*) AS invalid_record_status_count
FROM purgo_playground.patient_data
WHERE record_status IS NOT NULL
  AND record_status NOT IN ('active', 'inactive', 'pending');

-- Validate ingestion_date is a valid timestamp or NULL

WITH required_columns AS (
  SELECT 'patient_id' AS column_name, 'bigint' AS data_type, 'YES' AS is_nullable
  UNION ALL SELECT 'patient_name', 'string', 'YES'
  UNION ALL SELECT 'age', 'bigint', 'YES'
  UNION ALL SELECT 'diagnosis', 'string', 'YES'
  UNION ALL SELECT 'treatment', 'string', 'YES'
  UNION ALL SELECT 'ingestion_date', 'timestamp', 'YES'
  UNION ALL SELECT 'source_system', 'string', 'YES'
  UNION ALL SELECT 'record_status', 'string', 'YES'
  UNION ALL SELECT 'created_by', 'string', 'YES'
  UNION ALL SELECT 'modified_by', 'string', 'YES'
),
actual_columns AS (
  SELECT
    column_name,
    data_type,
    is_nullable
  FROM information_schema.columns
  WHERE table_catalog = 'purgo_databricks'
    AND table_schema = 'purgo_playground'
    AND table_name = 'patient_data'
)

SELECT COUNT(*) AS invalid_ingestion_date_count
FROM purgo_playground.patient_data
WHERE ingestion_date IS NOT NULL
  AND TRY_CAST(ingestion_date AS TIMESTAMP) IS NULL;

-- Validate source_system is non-empty string or NULL

WITH required_columns AS (
  SELECT 'patient_id' AS column_name, 'bigint' AS data_type, 'YES' AS is_nullable
  UNION ALL SELECT 'patient_name', 'string', 'YES'
  UNION ALL SELECT 'age', 'bigint', 'YES'
  UNION ALL SELECT 'diagnosis', 'string', 'YES'
  UNION ALL SELECT 'treatment', 'string', 'YES'
  UNION ALL SELECT 'ingestion_date', 'timestamp', 'YES'
  UNION ALL SELECT 'source_system', 'string', 'YES'
  UNION ALL SELECT 'record_status', 'string', 'YES'
  UNION ALL SELECT 'created_by', 'string', 'YES'
  UNION ALL SELECT 'modified_by', 'string', 'YES'
),
actual_columns AS (
  SELECT
    column_name,
    data_type,
    is_nullable
  FROM information_schema.columns
  WHERE table_catalog = 'purgo_databricks'
    AND table_schema = 'purgo_playground'
    AND table_name = 'patient_data'
)

SELECT COUNT(*) AS invalid_source_system_count
FROM purgo_playground.patient_data
WHERE source_system IS NOT NULL AND TRIM(source_system) = '';

-- Validate created_by is non-empty string or NULL

WITH required_columns AS (
  SELECT 'patient_id' AS column_name, 'bigint' AS data_type, 'YES' AS is_nullable
  UNION ALL SELECT 'patient_name', 'string', 'YES'
  UNION ALL SELECT 'age', 'bigint', 'YES'
  UNION ALL SELECT 'diagnosis', 'string', 'YES'
  UNION ALL SELECT 'treatment', 'string', 'YES'
  UNION ALL SELECT 'ingestion_date', 'timestamp', 'YES'
  UNION ALL SELECT 'source_system', 'string', 'YES'
  UNION ALL SELECT 'record_status', 'string', 'YES'
  UNION ALL SELECT 'created_by', 'string', 'YES'
  UNION ALL SELECT 'modified_by', 'string', 'YES'
),
actual_columns AS (
  SELECT
    column_name,
    data_type,
    is_nullable
  FROM information_schema.columns
  WHERE table_catalog = 'purgo_databricks'
    AND table_schema = 'purgo_playground'
    AND table_name = 'patient_data'
)

SELECT COUNT(*) AS invalid_created_by_count
FROM purgo_playground.patient_data
WHERE created_by IS NOT NULL AND TRIM(created_by) = '';

-- Validate modified_by is non-empty string or NULL

WITH required_columns AS (
  SELECT 'patient_id' AS column_name, 'bigint' AS data_type, 'YES' AS is_nullable
  UNION ALL SELECT 'patient_name', 'string', 'YES'
  UNION ALL SELECT 'age', 'bigint', 'YES'
  UNION ALL SELECT 'diagnosis', 'string', 'YES'
  UNION ALL SELECT 'treatment', 'string', 'YES'
  UNION ALL SELECT 'ingestion_date', 'timestamp', 'YES'
  UNION ALL SELECT 'source_system', 'string', 'YES'
  UNION ALL SELECT 'record_status', 'string', 'YES'
  UNION ALL SELECT 'created_by', 'string', 'YES'
  UNION ALL SELECT 'modified_by', 'string', 'YES'
),
actual_columns AS (
  SELECT
    column_name,
    data_type,
    is_nullable
  FROM information_schema.columns
  WHERE table_catalog = 'purgo_databricks'
    AND table_schema = 'purgo_playground'
    AND table_name = 'patient_data'
)

SELECT COUNT(*) AS invalid_modified_by_count
FROM purgo_playground.patient_data
WHERE modified_by IS NOT NULL AND TRIM(modified_by) = '';

-- Check for duplicate patient_id values

WITH required_columns AS (
  SELECT 'patient_id' AS column_name, 'bigint' AS data_type, 'YES' AS is_nullable
  UNION ALL SELECT 'patient_name', 'string', 'YES'
  UNION ALL SELECT 'age', 'bigint', 'YES'
  UNION ALL SELECT 'diagnosis', 'string', 'YES'
  UNION ALL SELECT 'treatment', 'string', 'YES'
  UNION ALL SELECT 'ingestion_date', 'timestamp', 'YES'
  UNION ALL SELECT 'source_system', 'string', 'YES'
  UNION ALL SELECT 'record_status', 'string', 'YES'
  UNION ALL SELECT 'created_by', 'string', 'YES'
  UNION ALL SELECT 'modified_by', 'string', 'YES'
),
actual_columns AS (
  SELECT
    column_name,
    data_type,
    is_nullable
  FROM information_schema.columns
  WHERE table_catalog = 'purgo_databricks'
    AND table_schema = 'purgo_playground'
    AND table_name = 'patient_data'
)

SELECT COUNT(*) AS duplicate_patient_id_count
FROM (

WITH required_columns AS (
  SELECT 'patient_id' AS column_name, 'bigint' AS data_type, 'YES' AS is_nullable
  UNION ALL SELECT 'patient_name', 'string', 'YES'
  UNION ALL SELECT 'age', 'bigint', 'YES'
  UNION ALL SELECT 'diagnosis', 'string', 'YES'
  UNION ALL SELECT 'treatment', 'string', 'YES'
  UNION ALL SELECT 'ingestion_date', 'timestamp', 'YES'
  UNION ALL SELECT 'source_system', 'string', 'YES'
  UNION ALL SELECT 'record_status', 'string', 'YES'
  UNION ALL SELECT 'created_by', 'string', 'YES'
  UNION ALL SELECT 'modified_by', 'string', 'YES'
),
actual_columns AS (
  SELECT
    column_name,
    data_type,
    is_nullable
  FROM information_schema.columns
  WHERE table_catalog = 'purgo_databricks'
    AND table_schema = 'purgo_playground'
    AND table_name = 'patient_data'
)

SELECT patient_id
  FROM purgo_playground.patient_data
  WHERE patient_id IS NOT NULL
  GROUP BY patient_id
  HAVING COUNT(*) > 1
) dupes;

-- Display the updated patient_data table with all required columns

WITH required_columns AS (
  SELECT 'patient_id' AS column_name, 'bigint' AS data_type, 'YES' AS is_nullable
  UNION ALL SELECT 'patient_name', 'string', 'YES'
  UNION ALL SELECT 'age', 'bigint', 'YES'
  UNION ALL SELECT 'diagnosis', 'string', 'YES'
  UNION ALL SELECT 'treatment', 'string', 'YES'
  UNION ALL SELECT 'ingestion_date', 'timestamp', 'YES'
  UNION ALL SELECT 'source_system', 'string', 'YES'
  UNION ALL SELECT 'record_status', 'string', 'YES'
  UNION ALL SELECT 'created_by', 'string', 'YES'
  UNION ALL SELECT 'modified_by', 'string', 'YES'
),
actual_columns AS (
  SELECT
    column_name,
    data_type,
    is_nullable
  FROM information_schema.columns
  WHERE table_catalog = 'purgo_databricks'
    AND table_schema = 'purgo_playground'
    AND table_name = 'patient_data'
)

SELECT
  patient_id,
  patient_name,
  age,
  diagnosis,
  treatment,
  ingestion_date,
  source_system,
  record_status,
  created_by,
  modified_by
FROM purgo_playground.patient_data
ORDER BY patient_id;

-- END OF SCRIPT
