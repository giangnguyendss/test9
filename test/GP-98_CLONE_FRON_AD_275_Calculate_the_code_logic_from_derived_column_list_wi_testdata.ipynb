# %%
# %csv
### purgo_playground.enriched_patient_therapy_shipment
## Test Data Categories
product,ship_date,days_supply,qty,treatment_id,dob,first_ship_date,refill_status,patient_id,ship_type,shipment_arrived_status,delivery_ontime,shipment_expiry,discontinuation_date,days_until_next_ship,days_since_last_fill,expected_refill_date,prior_ship,days_between,days_since_supply_out,age,age_at_first_ship,latest_therapy_ships,discontinuation_type
DrugA,2024-01-01,28,"84",TREAT001,1980-05-10,2024-01-01,DC - Standard,PAT001,commercial,arrived,yes,2024-01-29,2024-04-29,0,29,2024-01-29,NULL,NULL,NULL,43,44,3,STANDARD
DrugB,2024-02-15,NULL,"63",TREAT002,1975-12-20,2024-02-15,DC-PERMANENT,PAT002,commercial,arrived,no,2024-03-20,2024-06-19,0,34,2024-03-20,NULL,NULL,NULL,48,49,1,PERMANENT
DrugC,2024-03-10,30,"90",TREAT003,1990-07-01,2024-03-10,ACTIVE,PAT003,commercial,pending,yes,2024-04-09,2024-07-09,1,31,2024-04-10,NULL,NULL,NULL,33,34,1,NULL
DrugD,2024-04-05,NULL,"21",TREAT004,2000-01-01,2024-04-05,DC - Standard,PAT004,noncommercial,arrived,yes,2024-04-54,2024-07-54,0,26,2024-05-01,NULL,NULL,NULL,24,24,0,STANDARD
DrugE,2024-05-20,14,"42",TREAT005,1965-03-15,2024-05-20,DC-PERMANENT,PAT005,commercial,arrived,yes,2024-06-03,2024-09-02,7,21,2024-06-10,NULL,NULL,NULL,59,59,1,PERMANENT


### purgo_playground.patient_therapy_shipment
## Test Data Categories
product,ship_date,days_supply,qty,treatment_id,dob,first_ship_date,refill_status,patient_id,ship_type,shipment_arrived_status,delivery_ontime,calctime
DrugA,2024-01-01,28,84,TREAT001,1980-05-10,2024-01-01,DC - Standard,PAT001,commercial,arrived,yes,2024-01-29T00:00:00.000+0000
DrugB,2024-02-15,NULL,63,TREAT002,1975-12-20,2024-02-15,DC-PERMANENT,PAT002,commercial,arrived,no,2024-03-20T00:00:00.000+0000
DrugC,2024-03-10,30,90,TREAT003,1990-07-01,2024-03-10,ACTIVE,PAT003,commercial,pending,yes,2024-04-10T00:00:00.000+0000
DrugD,2024-04-05,NULL,21,TREAT004,2000-01-01,2024-04-05,DC - Standard,PAT004,noncommercial,arrived,yes,2024-05-01T00:00:00.000+0000
DrugE,2024-05-20,14,42,TREAT005,1965-03-15,2024-05-20,DC-PERMANENT,PAT005,commercial,arrived,yes,2024-06-10T00:00:00.000+0000


### purgo_playground.patient_therapy_shipment_stg
## Test Data Categories
patient_id,treatment_id,product,ship_date,shipment_expiry,discontinuation_date,days_until_next_ship,days_since_last_fill,expected_refill_date,prior_ship,days_between,days_since_supply_out,age,age_at_first_ship,latest_therapy_ships,discontinuation_type
PAT001,TREAT001,DrugA,2024-01-01,2024-01-29,2024-04-29,0,29,2024-01-29,NULL,NULL,NULL,43,44,3,STANDARD
PAT002,TREAT002,DrugB,2024-02-15,2024-03-20,2024-06-19,0,34,2024-03-20,NULL,NULL,NULL,48,49,1,PERMANENT
PAT003,TREAT003,DrugC,2024-03-10,2024-04-09,2024-07-09,1,31,2024-04-10,NULL,NULL,NULL,33,34,1,NULL
PAT004,TREAT004,DrugD,2024-04-05,2024-04-54,2024-07-54,0,26,2024-05-01,NULL,NULL,NULL,24,24,0,STANDARD
PAT005,TREAT005,DrugE,2024-05-20,2024-06-03,2024-09-02,7,21,2024-06-10,NULL,NULL,NULL,59,59,1,PERMANENT


### purgo_playground.wrk_patient_therapy_shipment
## Test Data Categories
product,ship_date,days_supply,qty,treatment_id,dob,first_ship_date,refill_status,patient_id,ship_type,shipment_arrived_status,delivery_ontime,calctime
DrugA,2024-01-01,28,84,TREAT001,1980-05-10,2024-01-01,DC - Standard,PAT001,commercial,arrived,yes,2024-01-29T00:00:00.000+0000
DrugB,2024-02-15,NULL,63,TREAT002,1975-12-20,2024-02-15,DC-PERMANENT,PAT002,commercial,arrived,no,2024-03-20T00:00:00.000+0000
DrugC,2024-03-10,30,90,TREAT003,1990-07-01,2024-03-10,ACTIVE,PAT003,commercial,pending,yes,2024-04-10T00:00:00.000+0000
DrugD,2024-04-05,NULL,21,TREAT004,2000-01-01,2024-04-05,DC - Standard,PAT004,noncommercial,arrived,yes,2024-05-01T00:00:00.000+0000
DrugE,2024-05-20,14,42,TREAT005,1965-03-15,2024-05-20,DC-PERMANENT,PAT005,commercial,arrived,yes,2024-06-10T00:00:00.000+0000
