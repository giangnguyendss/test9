# %%
# %csv
### purgo_databricks.purgo_playground.d_product_revenue_stg
## Test Data Categories
country,product_type,months_in_top_3,performance,start_date,end_date
US,Tablet,12,Excellent,2024-01-01,2024-12-31
UK,Injection,0,Poor,2024-06-01,2024-06-30
DE,Tablet,36,Good,2022-01-01,2025-01-01
FR,Tablet,NULL,Moderate,NULL,NULL
JP,"Tablet, Extended Release",24,"Excellent",2023-01-01,2025-01-01


### purgo_databricks.purgo_playground.product_type_performance_summary_stg
## Test Data Categories
country,product_type,months_in_top_3,performance,start_date,end_date
US,Tablet,12,Excellent,2024-01-01T00:00:00.000+0000,2024-12-31T23:59:59.000+0000
UK,Injection,0,Poor,2024-06-01T00:00:00.000+0000,2024-06-30T23:59:59.000+0000
DE,Tablet,36,Good,2022-01-01T00:00:00.000+0000,2025-01-01T00:00:00.000+0000
FR,Tablet,NULL,Moderate,NULL,NULL
JP,"Tablet, Extended Release",24,"Excellent",2023-01-01T00:00:00.000+0000,2025-01-01T00:00:00.000+0000


### purgo_databricks.purgo_playground.territory_sales_achievement_raw
## Test Data Categories
territory_level,team_name,target_month,territory_id,territory_rep_employee_id,district_id,district_rep_employee_id,brand_name,target_type,target_value,actual_value,cycle_name
Territory,Alpha,2024-06,TR001,1001,2001,3001,BrandA,Primary,100000.0,105000.0,Cycle1
District,Beta,2024-07,TR002,1002,2002,3002,BrandB,Secondary,50000.0,45000.0,Cycle2
Region,Gamma,2024-08,TR003,1003,2003,3003,BrandC,Primary,75000.0,75000.0,Cycle3
National,Delta,2024-09,TR004,NULL,2004,3004,BrandD,Primary,NULL,90000.0,Cycle4
Territory,Epsilon,2024-10,TR005,1005,2005,3005,"BrandE, Special",Primary,120000.0,110000.0,Cycle5


### purgo_databricks.purgo_playground.sales_kpi
## Test Data Categories
sales_year,sales_product_id,product_name,market_segment,total_sales,prev_year_sales,yoy_growth_pct,avg_market_share,market_penetration_flag,sales_rank
2024,PRD001,Tablet,Hospital,100000,90000,11.11,25.5,Yes,1
2024,PRD002,Injection,Clinic,50000,60000,-16.67,10.0,No,2
2023,PRD003,Tablet,Pharmacy,75000,70000,7.14,15.0,Yes,3
2022,PRD004,Tablet,Hospital,0,50000,-100.0,0.0,No,4
2024,PRD005,"Tablet, Extended Release",Hospital,120000,110000,9.09,30.0,Yes,5


### purgo_databricks.purgo_playground.wrk_product_type_performance_summary
## Test Data Categories
country,product_type,months_in_top_3,performance,start_date,end_date
US,Tablet,12,Excellent,2024-01-01T00:00:00.000+0000,2024-12-31T23:59:59.000+0000
UK,Injection,0,Poor,2024-06-01T00:00:00.000+0000,2024-06-30T23:59:59.000+0000
DE,Tablet,36,Good,2022-01-01T00:00:00.000+0000,2025-01-01T00:00:00.000+0000
FR,Tablet,NULL,Moderate,NULL,NULL
JP,"Tablet, Extended Release",24,"Excellent",2023-01-01T00:00:00.000+0000,2025-01-01T00:00:00.000+0000


### purgo_databricks.purgo_playground.t3_territory_sales_achievement
## Test Data Categories
territory_id,district_id,region_id,national_id,territory_level,territory_team_name,brand_name,target_month,target_value,territory_info,district_info,region_info,national_info,actual_value
TR001,DI001,RG001,NA001,Territory,Alpha,BrandA,2024-06-01,100000.000000000000000,Info1,Dist1,Reg1,Nat1,105000.0
TR002,DI002,RG002,NA002,District,Beta,BrandB,2024-07-01,50000.000000000000000,Info2,Dist2,Reg2,Nat2,45000.0
TR003,DI003,RG003,NA003,Region,Gamma,BrandC,2024-08-01,75000.000000000000000,Info3,Dist3,Reg3,Nat3,75000.0
TR004,DI004,RG004,NA004,National,Delta,BrandD,2024-09-01,NULL,Info4,Dist4,Reg4,Nat4,90000.0
TR005,DI005,RG005,NA005,Territory,Epsilon,"BrandE, Special",2024-10-01,120000.000000000000000,Info5,Dist5,Reg5,Nat5,110000.0


### purgo_databricks.purgo_playground.territory_sales_achievement_raw_territory_stg
## Test Data Categories
team_name,territory_id,brand_name,cycle_name,sum_actual_value,sum_target_value,territory_achievement,rank
Alpha,TR001,BrandA,Cycle1,105000.0,100000.0,105.0,1
Beta,TR002,BrandB,Cycle2,45000.0,50000.0,90.0,2
Gamma,TR003,BrandC,Cycle3,75000.0,75000.0,100.0,3
Delta,TR004,BrandD,Cycle4,90000.0,NULL,NULL,4
Epsilon,TR005,"BrandE, Special",Cycle5,110000.0,120000.0,91.67,5


### purgo_databricks.purgo_playground.wrk_territory_sales_achievement_raw
## Test Data Categories
territory_level,team_name,target_month,territory_id,territory_rep_employee_id,district_id,district_rep_employee_id,brand_name,target_type,target_value,actual_value,cycle_name
Territory,Alpha,2024-06,TR001,1001,2001,3001,BrandA,Primary,100000.0,105000.0,Cycle1
District,Beta,2024-07,TR002,1002,2002,3002,BrandB,Secondary,50000.0,45000.0,Cycle2
Region,Gamma,2024-08,TR003,1003,2003,3003,BrandC,Primary,75000.0,75000.0,Cycle3
National,Delta,2024-09,TR004,NULL,2004,3004,BrandD,Primary,NULL,90000.0,Cycle4
Territory,Epsilon,2024-10,TR005,1005,2005,3005,"BrandE, Special",Primary,120000.0,110000.0,Cycle5


### purgo_databricks.purgo_playground.territory_sales_achievement
## Test Data Categories
territory_id,district_id,region_id,national_id,territory_level,territory_team_name,brand_name,target_month,target_value,territory_info,district_info,region_info,national_info,actual_value
TR001,DI001,RG001,NA001,Territory,Alpha,BrandA,2024-06-01,100000.000000000000000,Info1,Dist1,Reg1,Nat1,105000.0
TR002,DI002,RG002,NA002,District,Beta,BrandB,2024-07-01,50000.000000000000000,Info2,Dist2,Reg2,Nat2,45000.0
TR003,DI003,RG003,NA003,Region,Gamma,BrandC,2024-08-01,75000.000000000000000,Info3,Dist3,Reg3,Nat3,75000.0
TR004,DI004,RG004,NA004,National,Delta,BrandD,2024-09-01,NULL,Info4,Dist4,Reg4,Nat4,90000.0
TR005,DI005,RG005,NA005,Territory,Epsilon,"BrandE, Special",2024-10-01,120000.000000000000000,Info5,Dist5,Reg5,Nat5,110000.0


### purgo_databricks.purgo_playground.territory_sales_target_new
## Test Data Categories
territory_id,territory_name,territory_level,territory_team_name,brand_id,sales_channel,brand_name,target_month,sales_month,currency_code,currency,source_system_name,delivery_file_name,district_id,region_id,country_code,country_name,national_id,cdm_created_by,cdm_created_on,cdm_last_updated_by,cdm_last_updated_on,dl_etl_timestamp,dl_btach_number,target_type,target_value,operation_flag
TR001,North,Region,Alpha,BR001,Online,BrandA,2024-06-01,2024-06-01,USD,Dollar,SAP,File1.csv,DI001,RG001,US,United States,NA001,admin,2024-05-01T10:00:00.000+0000,admin,2024-05-01T10:00:00.000+0000,2024-05-01T10:00:00.000+0000,1,Primary,100000.000000000000000,NEW
TR002,South,District,Beta,BR002,Offline,BrandB,2024-07-01,2024-07-01,EUR,Euro,Oracle,File2.csv,DI002,RG002,DE,Germany,NA002,admin,2024-05-02T11:00:00.000+0000,admin,2024-05-02T11:00:00.000+0000,2024-05-02T11:00:00.000+0000,2,Secondary,50000.000000000000000,UPDATE
TR003,East,Territory,Gamma,BR003,Online,BrandC,2024-08-01,2024-08-01,GBP,Pound,SAP,File3.csv,DI003,RG003,UK,United Kingdom,NA003,admin,2024-05-03T12:00:00.000+0000,admin,2024-05-03T12:00:00.000+0000,2024-05-03T12:00:00.000+0000,3,Primary,75000.000000000000000,NEW
TR004,West,National,Delta,BR004,Offline,BrandD,2024-09-01,2024-09-01,JPY,Yen,Oracle,File4.csv,DI004,RG004,JP,Japan,NA004,admin,2024-05-04T13:00:00.000+0000,admin,2024-05-04T13:00:00.000+0000,2024-05-04T13:00:00.000+0000,4,Primary,NULL,DELETE
TR005,Central,Territory,Epsilon,BR005,Online,"BrandE, Special",2024-10-01,2024-10-01,CNY,Yuan,SAP,File5.csv,DI005,RG005,CN,China,NA005,admin,2024-05-05T14:00:00.000+0000,admin,2024-05-05T14:00:00.000+0000,2024-05-05T14:00:00.000+0000,5,Primary,120000.000000000000000,NEW
