# %%
# %csv
### purgo_playground.sales_transactions
## Test Data Categories
transaction_id,rep_id,sales_amount,bonus_eligibility,performance_flag,product_perf_band,transaction_date
1,101,26000,Yes,High,Excellent,2025-10-01T09:00:00.000+0000
2,102,9000,Medium,Good,2025-10-02T10:15:00.000+0000
3,103,5000,No,Low,Poor,2025-10-03T11:30:00.000+0000
4,104,NULL,NULL,NULL,NULL,2025-10-04T12:45:00.000+0000
5,105,"abc",No,Low,Poor,2025-10-05T14:00:00.000+0000


### purgo_playground.rep_summary
## Test Data Categories
rep_id,total_rep_sales,rep_tier,bonus_eligibility
101,50000,Platinum Plus,Yes
102,35000,Gold,No
103,25000,Silver,No
104,NULL,NULL,NULL
105,"xyz",NULL,NULL


### purgo_playground.final_output
## Test Data Categories
transaction_id,rep_id,sales_amount,bonus_eligibility,performance_flag,product_perf_band,transaction_date,rep_tier
1,101,26000,Yes,High,Excellent,2025-10-01T09:00:00.000+0000,Platinum Plus
2,102,9000,Medium,Good,2025-10-02T10:15:00.000+0000,Gold
3,103,5000,No,Low,Poor,2025-10-03T11:30:00.000+0000,Silver
4,104,NULL,NULL,NULL,NULL,2025-10-04T12:45:00.000+0000,NULL
5,105,"abc",No,Low,Poor,2025-10-05T14:00:00.000+0000,NULL
