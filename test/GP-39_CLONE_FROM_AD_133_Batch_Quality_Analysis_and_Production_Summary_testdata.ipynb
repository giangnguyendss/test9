# %%
# %csv
### purgo_playground.batch_qc

## Test Data Categories
batch_id,product_name,production_date,quantity,quality_check_score
BATCH001,WidgetA,2025-10-01,100,98.5
BATCH002,WidgetB,2025-10-02,200,97.0
BATCH003,WidgetC,2025-10-03,150,96.99
BATCH004,WidgetD,2025-10-04,50,0.0
BATCH005,NULL,2025-10-05,120,NULL


### purgo_playground.product_wise_batch_qc_stg

## Test Data Categories
product_name,total_batches,passed_batches,failed_batches,percentage_passed
WidgetA,10,8,2,80.0
WidgetB,5,5,0,100.0
WidgetC,7,3,4,42.86
WidgetD,1,0,1,0.0
WidgetE,2,2,0,100.0


### purgo_playground.batch_wise_quality_status_stg

## Test Data Categories
batch_id,product_name,quality_check_score,quality_status
BATCH001,WidgetA,98.5,pass
BATCH002,WidgetB,97.0,pass
BATCH003,WidgetC,96.99,fail
BATCH004,WidgetD,0.0,fail
BATCH006,"",99.0,pass


### purgo_playground.batch_qc_summary_stg

## Test Data Categories
total_batches,total_passed_batches,total_failed_batches
25,18,7
5,5,0
10,8,2
1,0,1
NULL,NULL,NULL


### purgo_playground.batch_summary

## Test Data Categories
batch_id,product_name,quality_check_score,quality_status
BATCH001,WidgetA,98.5,pass
BATCH002,WidgetB,97.0,pass
BATCH003,WidgetC,96.99,fail
BATCH004,WidgetD,0.0,fail
BATCH007,WidgetF,-1,fail
