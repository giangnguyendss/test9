# %%
# %csv
### purgo_playground.compound_drug_analysis
## Test Data Categories
study_id,compound_id,mutation_id,therapeutic_area,drug_name,ic50,auc,efficacy,toxicity,potency,sample_size,mutation_frequency,mutation_severity,compound_concentration,cell_viability,growth_inhibition,result,approved_flag,validation_status,status,created_by,score1,score2,score3,score4,score5
S001,C001,M001,Oncology,"DrugA",0.45,0.80,0.75,0.10,0.90,200,5,2,1.5,0.85,0.60,"Positive",1,"valid","active","user1",80.0,85.0,90.0,75.0,80.0
S002,C002,M002,Cardiology,"DrugB",1.20,1.00,0.90,0.20,0.80,150,3,1,2.0,0.90,0.70,"Negative",1,"valid","completed","user2",65.0,62.0,68.0,66.0,64.0
S003,C003,M003,Neurology,"DrugC",0.70,0.60,0.50,0.15,0.70,300,7,3,1.2,0.80,0.55,"Positive",0,"valid","active","user3",55.0,58.0,59.0,57.0,56.0
S004,C004,M004,Immunology,"DrugD",0.90,0.70,0.80,0.12,0.85,250,4,2,1.8,0.88,0.65,"Negative",1,"invalid","pending","user4",100.0,100.0,100.0,100.0,100.0
S005,C005,M005,Endocrinology,"DrugE",1.10,1.20,1.00,0.18,0.95,220,6,2,2.2,0.92,0.75,"Positive",NULL,"valid","active","user5",70.0,70.0,70.0,70.0,70.0


### purgo_playground.compound_drug_analysis_stg
## Test Data Categories
compound_id,avg_dose_mg,avg_response_pct,avg_efficacy,avg_ic50,avg_auc,experiment_count,potency_level
C001,50.0,80.0,0.75,0.45,0.80,5,"High"
C002,60.0,65.0,0.90,1.20,1.00,3,"Moderate"
C003,55.0,50.0,0.50,0.70,0.60,7,"Low"
C004,70.0,90.0,0.80,0.90,0.70,4,"High"
C005,NULL,NULL,NULL,NULL,NULL,NULL,NULL


### purgo_playground.compound_screening_result_analysis
## Test Data Categories
study_id,compound_id,mutation_id,therapeutic_area,drug_name,ic50,auc,efficacy,toxicity,potency,sample_size,mutation_frequency,mutation_severity,compound_concentration,cell_viability,growth_inhibition,result,approved_flag,validation_status,status,created_by,score1,score2,score3,score4,score5,avg_ic50,avg_auc,avg_efficacy,total_sample_size,study_count,overall_score,potential_category
S001,C001,M001,Oncology,"DrugA",0.45,0.80,0.75,0.10,0.90,200,5,2,1.5,0.85,0.60,"Positive","1","valid","active","user1",80.0,85.0,90.0,75.0,80.0,0.50,0.80,0.70,1000,5,82.0,"High Potential"
S002,C002,M002,Cardiology,"DrugB",1.20,1.00,0.90,0.20,0.80,150,3,1,2.0,0.90,0.70,"Negative","1","valid","completed","user2",65.0,62.0,68.0,66.0,64.0,1.20,1.00,0.90,800,3,65.0,"Moderate Potential"
S003,C003,M003,Neurology,"DrugC",0.70,0.60,0.50,0.15,0.70,300,7,3,1.2,0.80,0.55,"Positive","0","valid","active","user3",55.0,58.0,59.0,57.0,56.0,0.70,0.60,0.50,1200,7,57.0,"Low Potential"
S004,C004,M004,Immunology,"DrugD",0.90,0.70,0.80,0.12,0.85,250,4,2,1.8,0.88,0.65,"Negative","1","invalid","pending","user4",100.0,100.0,100.0,100.0,100.0,0.90,0.70,0.80,950,4,100.0,"High Potential"
S005,C005,M005,UnknownArea,"DrugE",1.10,1.20,1.00,0.18,0.95,220,6,2,2.2,0.92,0.75,"Positive","1","valid","active","user5",NULL,70.0,70.0,70.0,70.0,NULL,NULL,NULL,NULL,NULL,NULL,"Unknown"


### purgo_playground.study_therapeutic_analysis_results_stg
## Test Data Categories
therapeutic_area,total_studies,completed_studies,ongoing_studies,avg_enrolled_subjects
Oncology,5,3,2,200.0
Cardiology,3,2,1,150.0
Neurology,7,5,2,300.0
Immunology,4,2,2,250.0
Endocrinology,NULL,NULL,NULL,NULL


### purgo_playground.study_therapeutic_analysis_results
## Test Data Categories
therapeutic_area,total_studies,completed_studies,ongoing_studies,avg_enrolled_subjects
Oncology,5,3,2,200.0
Cardiology,3,2,1,150.0
Neurology,7,5,2,300.0
Immunology,4,2,2,250.0
Endocrinology,NULL,NULL,NULL,NULL


### purgo_playground.therapeutic_area_mapping
## Test Data Categories
product,program_group,therapeutic_area
"ProductA","Group1","Oncology"
"ProductB","Group2","Cardiology"
"ProductC","Group3","Neurology"
"ProductD","Group4","Immunology"
"ProductE","Group5",NULL


### purgo_playground.study_therapeutic_analysis_stg
## Test Data Categories
therapeutic_area,total_studies,completed_studies,ongoing_studies,avg_enrolled_subjects
Oncology,5,3,2,200.0
Cardiology,3,2,1,150.0
Neurology,7,5,2,300.0
Immunology,4,2,2,250.0
Endocrinology,NULL,NULL,NULL,NULL


### purgo_playground.study_therapeutic_analysis
## Test Data Categories
study_roll_number,Fsr,Fpr,Far,therapeutic_area,product_name,study_roll_type,study_title,study_description,is_imo_study,ctms_updated_dt,pmo_updated_dt,enrolled_subjects_update_dt,protocol_approved_planned_dt,study_conduct_status,study_mgmt_org_name,enrolled_subjects_qty
SR001,2025-01-01,2025-01-10,2025-01-15,Oncology,"ProductA","TypeA","TitleA","DescA",true,2025-01-05,2025-01-06,2025-01-07,2025-01-08,"Active","OrgA",200
SR002,2025-02-01,2025-02-10,2025-02-15,Cardiology,"ProductB","TypeB","TitleB","DescB",false,2025-02-05,2025-02-06,2025-02-07,2025-02-08,"Completed","OrgB",150
SR003,2025-03-01,2025-03-10,2025-03-15,Neurology,"ProductC","TypeC","TitleC","DescC",true,2025-03-05,2025-03-06,2025-03-07,2025-03-08,"Active","OrgC",300
SR004,2025-04-01,2025-04-10,2025-04-15,Immunology,"ProductD","TypeD","TitleD","DescD",false,2025-04-05,2025-04-06,2025-04-07,2025-04-08,"Ongoing","OrgD",250
SR005,NULL,NULL,NULL,Endocrinology,"ProductE","TypeE","TitleE","DescE",NULL,NULL,NULL,NULL,NULL,"Unknown","OrgE",NULL


### purgo_playground.pp_validation_results_stg
## Test Data Categories
plant_id_src,plant_id_tgt,plant_id_validation,plant_cd_src,plant_cd_tgt,plant_cd_validation,company_cd_src,company_cd_tgt,company_cd_validation,source_system_cd_src,source_system_cd_tgt,source_system_cd_validation,product_line_src,product_line_tgt,product_line_validation,primary_uom_cd_src,primary_uom_cd_tgt,primary_uom_cd_validation,global_uom_conversion_rate_src,global_uom_conversion_rate_tgt,global_uom_conversion_rate_validation,global_uom_cd_src,global_uom_cd_tgt,global_uom_cd_validation,lifecycle_status_src,lifecycle_status_tgt,lifecycle_status_validation,flais_active_src,flais_active_tgt,flais_active_validation,sales_rank_abc_src,sales_rank_abc_tgt,sales_rank_abc_validation,inventory_rank_abc_src,inventory_rank_abc_tgt,inventory_rank_abc_validation,make_buy_src,make_buy_tgt,make_buy_validation,missing_from_src,missing_from_tgt,error_message
101,201,"Valid","PLANT1","PLANT2","Valid","COMP1","COMP2","Valid","SYS1","SYS2","Valid","LINE1","LINE2","Valid","UOM1","UOM2","Valid",1.0,1.0,"Valid","GUOM1","GUOM2","Valid","Active","Inactive","Valid","Y","N","Valid","A","B","Valid","C","D","Valid","Make","Buy","Valid",NULL,NULL,NULL
102,202,"Invalid","PLANT3","PLANT4","Invalid","COMP3","COMP4","Invalid","SYS3","SYS4","Invalid","LINE3","LINE4","Invalid","UOM3","UOM4","Invalid",2.0,2.5,"Invalid","GUOM3","GUOM4","Invalid","Inactive","Active","Invalid","N","Y","Invalid","B","A","Invalid","D","C","Invalid","Buy","Make","Invalid","Missing1","Missing2","Error: Plant mismatch"
NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL
103,203,"Valid","PLANT5","PLANT6","Valid","COMP5","COMP6","Valid","SYS5","SYS6","Valid","LINE5","LINE6","Valid","UOM5","UOM6","Valid",NULL,3.0,"Invalid","GUOM5","GUOM6","Valid","Active","Active","Valid","Y","Y","Valid","A","A","Valid","C","C","Valid","Make","Make","Valid",NULL,NULL,NULL
104,204,"Valid","PLANT7","PLANT8","Valid","COMP7","COMP8","Valid","SYS7","SYS8","Valid","LINE7","LINE8","Valid","UOM7","UOM8","Valid",4.0,4.0,"Valid","GUOM7","GUOM8","Valid","Active","Inactive","Valid","Y","N","Valid","A","B","Valid","C","D","Valid","Make","Buy","Valid",NULL,NULL,NULL
105,205,"Invalid","PLANT9","PLANT10","Invalid","COMP9","COMP10","Invalid","SYS9","SYS10","Invalid","LINE9","LINE10","Invalid","UOM9","UOM10","Invalid",5.0,5.5,"Invalid","GUOM9","GUOM10","Invalid","Inactive","Active","Invalid","N","Y","Invalid","B","A","Invalid","D","C","Invalid","Buy","Make","Invalid","Missing3","Missing4","Error: UOM mismatch"
