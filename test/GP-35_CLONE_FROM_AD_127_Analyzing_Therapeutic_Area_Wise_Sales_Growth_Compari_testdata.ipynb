# %%
# %csv
### purgo_playground.hcp_overall_performance
## Test Data Categories
HCP_ID,Interaction_Type,Duration_Minutes,Follow_Ups,Sales_Amount,Revenue_Converted,Therapeutic_Area,Product,Sales_Date
HCP001,Call,30,2,15000,"USD","Cardiology","DrugA",2023-01-15
HCP002,Email,45,1,20000,"USD","Oncology","DrugB",2023-04-10
HCP003,Meeting,60,3,8000,"USD","Neurology","DrugC",2023-02-20
HCP004,Call,25,0,10000,"USD","Diabetes","DrugD",2023-03-05
HCP005,Email,40,1,NULL,"USD","Immunology","DrugE",2023-05-18


### purgo_playground.sales_data_transformed
## Test Data Categories
Sale_ID,Medicine_ID,Category,Continent,Revenue,Bonus_Eligibility,performance_flag,product_perf_band,rep_tier
S001,M001,Cardiology,Europe,15000.0,Yes,High,A,Gold
S002,M002,Oncology,Asia,20000.0,No,Medium,B,Silver
S003,M003,Neurology,North America,8000.0,Yes,Low,C,Bronze
S004,M004,Diabetes,Europe,10000.0,No,High,A,Gold
S005,M005,Immunology,Africa,NULL,Yes,Medium,B,Silver


### purgo_playground.sales_data
## Test Data Categories
Sale_ID,Medicine_ID,Category,Continent,Revenue
S001,M001,Cardiology,Europe,15000.0
S002,M002,Oncology,Asia,20000.0
S003,M003,Neurology,North America,8000.0
S004,M004,Diabetes,Europe,10000.0
S005,M005,Immunology,Africa,NULL


### purgo_playground.stg_us_sales
## Test Data Categories
Wholesaler_File_Name,Source_System_Name,Source_Product_ID,Source_Product_Description,Brand,Customer_ID,Customer_Name,Address_Line_1,City,State,Post_Code,Net_Sales,Gross_Sales,Packs,Units,Sales_Date,Volume,Country_Code,Bill_to_Customer_ID,Currency_Code,delivery_file_name
"file1.csv","SAP",101.0,"DrugA","Amgen",1001,"CustomerA","123 Main St","New York","NY","10001",15000,16000.0,"PackA",100,"2023-01-15",500,"US",1001.0,"USD","delivery1.csv"
"file2.csv","Oracle",102.0,"DrugB","Pfizer",1002,"CustomerB","456 Elm St","Los Angeles","CA","90001",20000,21000.0,"PackB",200,"2023-04-10",600,"US",1002.0,"USD","delivery2.csv"
"file3.csv","SAP",103.0,"DrugC","Novartis",1003,"CustomerC","789 Oak St","Chicago","IL","60601",8000,8500.0,"PackC",150,"2023-02-20",400,"US",1003.0,"USD","delivery3.csv"
"file4.csv","Oracle",104.0,"DrugD","Sanofi",1004,"CustomerD","321 Pine St","Houston","TX","77001",10000,10500.0,"PackD",120,"2023-03-05",300,"US",1004.0,"USD","delivery4.csv"
"file5.csv","SAP",105.0,"DrugE","Roche",1005,"CustomerE","654 Maple St","Phoenix","AZ","85001",NULL,12000.0,"PackE",NULL,"2023-05-18",NULL,"US",1005.0,"USD","delivery5.csv"


### purgo_playground.product_sales_data
## Test Data Categories
transaction_id,sales_product_id,sales_amount,sales_date
T001,SP001,15000,2023-01-15
T002,SP002,20000,2023-04-10
T003,SP003,8000,2023-02-20
T004,SP004,10000,2023-03-05
T005,SP005,NULL,2023-05-18


### purgo_playground.sales_kpi
## Test Data Categories
sales_year,sales_product_id,product_name,market_segment,total_sales,prev_year_sales,yoy_growth_pct,avg_market_share,market_penetration_flag,sales_rank
2023,SP001,DrugA,Cardiology,15000,12000,25.0,0.15,Yes,1
2023,SP002,DrugB,Oncology,20000,18000,11.1,0.20,No,2
2023,SP003,DrugC,Neurology,8000,9000,-11.1,0.10,Yes,3
2023,SP004,DrugD,Diabetes,10000,9500,5.3,0.12,No,4
2023,SP005,DrugE,Immunology,NULL,10000,NULL,0.08,Yes,5


### purgo_playground.itm_territory_sales
## Test Data Categories
amgen_product_id,product_name,amgen_brand_id,amgen_brand_name,brand_name,source_product_id,master_product_id,master_product_name,market_desc,market_code,ta_code,ta_name,units_per_pack,sales_channel,sales_sub_channel,sales_speciality,sales_month,sales_value,sales_unit,sales_pack,sales_volume,sales_volume_uom,sales_volume_mcg,sales_value_usd_discount,sales_value_discount,number_of_prescriptions,sales_net_official,distribution_margin,confidential_tender_sales,official_tender_sales,extra_confidential_discount,extra_official_discount,sales_actual_usd,sales_budget_usd,sales_gross_price_lcl,gross_sales_price_budget_usd,gross_sales_price_actual_usd,geography_id,geography_name,geography_code,territory_id,territory_name,business_unit,team_name,territory_description,territory_hierarchy_type,purpose,territory_employee_id,territory_employee_name,territory_employee_login_id,district_id,district_name,district_employee_id,district_employee_name,district_employee_login_id,region_id,region_name,region_employee_id,region_employee_name,region_employee_login_id,national_id,national_name,national_employee_id,national_employee_name,national_employee_login_id,source_geo_id,source_geo_name,currency_code,currency,source_system_code,source_system_name,delivery_file_name,delivery_period,country_code,country_name,active_ingredient,manufacturer,ship_to_master_customer_id,ship_to_master_mgen_customer_id,ship_to_master_customer_name,source_customer_code,mgen_customer_id,customer_name,address_line_1,city,postal_code,table_name,sub_territory_id,sub_territory_name,sub_territory_hierarchy_type,sub_territory_description,product_class,country_users_list,team_users_list,district_users_list,territory_users_list,region_users_list,mgen_brand_flag,alignment_type,province,IS_PARALLEL_FLAG,territory_employee_name_non_primary,district_employee_name_non_primary,national_employee_name_non_primary,region_employee_name_non_primary
AP001,DrugA,AB001,Amgen,Amgen,101,MP001,DrugA Master,Cardiology Market,MC001,TA001,Cardiology,10,Hospital,Primary,Cardiology,2023-01-01,"15000","UnitA","PackA","500","mg","500mg","1000","500","50","15000","100","500","1000","10","5","15000","14000","100","12000","13000","G001","USA","US01","T001","East","BU1","TeamA","East Territory","Hierarchy1","Sales","E001","John Doe","jdoe","D001","DistrictA","DE001","Jane Smith","jsmith","R001","RegionA","RE001","Bob Lee","blee","N001","NationalA","NE001","Alice Kim","akim","SG001","SourceGeoA","USD","USD","SYS001","SAP","file1.csv","2023Q1","US","United States","IngredientA","Amgen","CUST001","MGENCUST001","CustomerA","SC001","MGEN001","CustomerA","123 Main St","New York","10001","itm_territory_sales","ST001","SubTerritoryA","Hierarchy2","SubTerritoryDescA","ClassA","user1,user2","user3","user4","user5","user6","Y","Align1","NY","N","John Doe","Jane Smith","Alice Kim","Bob Lee"
AP002,DrugB,AB002,Pfizer,Pfizer,102,MP002,DrugB Master,Oncology Market,MC002,TA002,Oncology,20,Clinic,Secondary,Oncology,2023-04-01,"20000","UnitB","PackB","600","mg","600mg","2000","600","60","20000","200","600","2000","20","10","20000","18000","200","16000","17000","G002","USA","US02","T002","West","BU2","TeamB","West Territory","Hierarchy1","Sales","E002","Mary Lee","mlee","D002","DistrictB","DE002","Tom Brown","tbrown","R002","RegionB","RE002","Sue Park","spark","N002","NationalB","NE002","Chris Wu","cwu","SG002","SourceGeoB","USD","USD","SYS002","Oracle","file2.csv","2023Q2","US","United States","IngredientB","Pfizer","CUST002","MGENCUST002","CustomerB","SC002","MGEN002","CustomerB","456 Elm St","Los Angeles","90001","itm_territory_sales","ST002","SubTerritoryB","Hierarchy2","SubTerritoryDescB","ClassB","user7,user8","user9","user10","user11","user12","N","Align2","CA","Y","Mary Lee","Tom Brown","Chris Wu","Sue Park"
AP003,DrugC,AB003,Novartis,Novartis,103,MP003,DrugC Master,Neurology Market,MC003,TA003,Neurology,15,Hospital,Primary,Neurology,2023-02-01,"8000","UnitC","PackC","400","mg","400mg","500","400","40","8000","80","400","500","8","4","8000","9000","80","7000","7500","G003","USA","US03","T003","North","BU3","TeamC","North Territory","Hierarchy1","Sales","E003","Sam Lee","slee","D003","DistrictC","DE003","Kim Tran","ktran","R003","RegionC","RE003","Paul Lim","plim","N003","NationalC","NE003","Linda Ho","lho","SG003","SourceGeoC","USD","USD","SYS003","SAP","file3.csv","2023Q1","US","United States","IngredientC","Novartis","CUST003","MGENCUST003","CustomerC","SC003","MGEN003","CustomerC","789 Oak St","Chicago","60601","itm_territory_sales","ST003","SubTerritoryC","Hierarchy2","SubTerritoryDescC","ClassC","user13,user14","user15","user16","user17","user18","Y","Align3","IL","N","Sam Lee","Kim Tran","Linda Ho","Paul Lim"
AP004,DrugD,AB004,Sanofi,Sanofi,104,MP004,DrugD Master,Diabetes Market,MC004,TA004,Diabetes,12,Clinic,Secondary,Diabetes,2023-03-01,"10000","UnitD","PackD","300","mg","300mg","1500","300","30","10000","60","300","1500","12","6","10000","9500","60","8000","8500","G004","USA","US04","T004","South","BU4","TeamD","South Territory","Hierarchy1","Sales","E004","Peter Kim","pkim","D004","DistrictD","DE004","Nancy Lee","nlee","R004","RegionD","RE004","Eric Choi","echoi","N004","NationalD","NE004","Grace Lin","glin","SG004","SourceGeoD","USD","USD","SYS004","Oracle","file4.csv","2023Q1","US","United States","IngredientD","Sanofi","CUST004","MGENCUST004","CustomerD","SC004","MGEN004","CustomerD","321 Pine St","Houston","77001","itm_territory_sales","ST004","SubTerritoryD","Hierarchy2","SubTerritoryDescD","ClassD","user19,user20","user21","user22","user23","user24","N","Align4","TX","Y","Peter Kim","Nancy Lee","Grace Lin","Eric Choi"
AP005,DrugE,AB005,Roche,Roche,105,MP005,DrugE Master,Immunology Market,MC005,TA005,Immunology,18,Hospital,Primary,Immunology,2023-05-01,"NULL","UnitE","PackE","NULL","mg","NULL","NULL","NULL","NULL","NULL","NULL","NULL","NULL","NULL","NULL","NULL","NULL","NULL","NULL","NULL","G005","USA","US05","T005","Central","BU5","TeamE","Central Territory","Hierarchy1","Sales","E005","Anna Park","apark","D005","DistrictE","DE005","David Kim","dkim","R005","RegionE","RE005","Helen Lee","hlee","N005","NationalE","NE005","Kevin Wu","kwu","SG005","SourceGeoE","USD","USD","SYS005","SAP","file5.csv","2023Q2","US","United States","IngredientE","Roche","CUST005","MGENCUST005","CustomerE","SC005","MGEN005","CustomerE","654 Maple St","Phoenix","85001","itm_territory_sales","ST005","SubTerritoryE","Hierarchy2","SubTerritoryDescE","ClassE","user25,user26","user27","user28","user29","user30","Y","Align5","AZ","N","Anna Park","David Kim","Kevin Wu","Helen Lee"


### purgo_playground.product_marketshare_data
## Test Data Categories
ms_product_id,market_share_pct
SP001,15.0
SP002,20.0
SP003,10.0
SP004,12.0
SP005,NULL


### purgo_playground.sales_info
## Test Data Categories
Sale_ID,Product_ID,Batch_ID,Sale_Quantity,Sale_Date,Region,Sale_Price_Per_Unit
S001,P001,B001,100,2023-01-15,East,150
S002,P002,B002,200,2023-04-10,West,200
S003,P003,B003,80,2023-02-20,North,100
S004,P004,B004,120,2023-03-05,South,130
S005,P005,B005,NULL,2023-05-18,Central,180


### purgo_playground.d_product_revenue_stg
## Test Data Categories
country,product_type,months_in_top_3,performance,start_date,end_date
USA,Cardiology,12,High,2023-01-01,2023-12-31
USA,Oncology,10,Medium,2023-04-01,2023-12-31
USA,Neurology,8,Low,2023-02-01,2023-12-31
USA,Diabetes,6,High,2023-03-01,2023-12-31
USA,Immunology,NULL,Medium,2023-05-01,2023-12-31
