# %%
# %csv
### purgo_playground.dw_ap_sla_aging_invoice_ca
## Happy path
cost_center_segment,gl_balancing_segment,gl_segment1,gl_code_combination_id,invoiced_on_date,invoice_id,invoice_type_code,transaction_currency_code,ledger_currency_code,invoice_schedule_due_date,payables_bu_id,natural_account_segment,invoice_accounting_date,invoice_number,supplier_party_id,supplier_site_id,invoice_source_code,snapshot_captured_date
4001,700,1001,123456,2025-09-24,INV001,STANDARD,USD,USD,2025-10-01,100,4500,2025-09-24,INV-2025-001,SP001,SS001,ORAFIN,2025-09-25T12:00:00.000+0000
9000,400,9999,654321,2024-01-15,INV002,PREPAYMENT,EUR,EUR,2024-02-01,200,8999,2024-01-15,INV-2024-002,SP002,SS002,ORAFIN,2024-01-16T08:30:00.000+0000
5000,400,2000,789012,2023-12-31,INV003,STANDARD,GBP,GBP,2024-01-10,300,4000,2023-12-31,INV-2023-003,SP003,SS003,ORAFIN,2023-12-31T23:59:59.000+0000

## Edge cases
cost_center_segment,gl_balancing_segment,gl_segment1,gl_code_combination_id,invoiced_on_date,invoice_id,invoice_type_code,transaction_currency_code,ledger_currency_code,invoice_schedule_due_date,payables_bu_id,natural_account_segment,invoice_accounting_date,invoice_number,supplier_party_id,supplier_site_id,invoice_source_code,snapshot_captured_date
9000,900,9999,999999,2022-01-01,INV004,"",JPY,JPY,2022-01-02,999,4000,2022-01-01,"",SP004,SS004,ORAFIN,2022-01-01T00:00:00.000+0000
4001,400,1001,1,2025-12-31,INV005,STANDARD,"",USD,2026-01-01,1,4500,2025-12-31,INV-2025-005,SP005,SS005,ORAFIN,2025-12-31T23:59:59.000+0000
5000,700,2000,0,2023-01-01,INV006,PREPAYMENT,EUR,"",2023-01-02,0,8999,2023-01-01,INV-2023-006,SP006,SS006,ORAFIN,2023-01-01T00:00:00.000+0000

## Error cases
cost_center_segment,gl_balancing_segment,gl_segment1,gl_code_combination_id,invoiced_on_date,invoice_id,invoice_type_code,transaction_currency_code,ledger_currency_code,invoice_schedule_due_date,payables_bu_id,natural_account_segment,invoice_accounting_date,invoice_number,supplier_party_id,supplier_site_id,invoice_source_code,snapshot_captured_date
4001,700,1001,123456,2025-09-24,INV001,STANDARD,USD,USD,2025-10-01,100,3500,2025-09-24,INV-2025-001,SP001,SS001,Receivables,2025-09-25T12:00:00.000+0000
9000,400,9999,654321,2024-01-15,INV002,PREPAYMENT,EUR,EUR,2024-02-01,200,8999,2024-01-15,INV-2024-002,00032238,SS002,ORAFIN,2024-01-16T08:30:00.000+0000
5000,400,2000,789012,2023-12-31,INV003,STANDARD,GBP,GBP,2024-01-10,300,4000,2023-12-31,INV-2023-003,SP003,SS003,MAINFRAME,2023-12-31T23:59:59.000+0000

## NULL handling
cost_center_segment,gl_balancing_segment,gl_segment1,gl_code_combination_id,invoiced_on_date,invoice_id,invoice_type_code,transaction_currency_code,ledger_currency_code,invoice_schedule_due_date,payables_bu_id,natural_account_segment,invoice_accounting_date,invoice_number,supplier_party_id,supplier_site_id,invoice_source_code,snapshot_captured_date
NULL,700,1001,123456,2025-09-24,INV007,STANDARD,USD,USD,2025-10-01,100,4500,2025-09-24,INV-2025-007,SP007,SS007,ORAFIN,2025-09-25T12:00:00.000+0000
4001,NULL,1001,654321,2024-01-15,INV008,PREPAYMENT,EUR,EUR,2024-02-01,200,8999,2024-01-15,INV-2024-008,SP008,SS008,ORAFIN,2024-01-16T08:30:00.000+0000
5000,400,NULL,789012,2023-12-31,INV009,STANDARD,GBP,GBP,2024-01-10,300,4000,2023-12-31,INV-2023-009,SP009,SS009,ORAFIN,2023-12-31T23:59:59.000+0000


### purgo_playground.dw_ap_sla_expense_dist_cf
## Happy path
invoice_distribution_id,natural_account_segment,gl_balancing_segment,cost_center_segment,gl_segment1,gl_code_combination_id,invoice_id,distribution_line_number,invoice_line_number,invoice_accounting_date,transaction_amount,xla_manual_override_flag,invoice_description,invoice_source_code
10001,4500,700,4001,1001,123456,INV001,1,1,2025-09-24,1000.50,N,"Office Supplies",ORAFIN
10002,8999,400,9000,9999,654321,INV002,2,1,2024-01-15,2500.00,Y,"Consulting Services",ORAFIN
10003,4000,400,5000,2000,789012,INV003,1,2,2023-12-31,500.75,N,"Travel Expenses",ORAFIN

## Edge cases
invoice_distribution_id,natural_account_segment,gl_balancing_segment,cost_center_segment,gl_segment1,gl_code_combination_id,invoice_id,distribution_line_number,invoice_line_number,invoice_accounting_date,transaction_amount,xla_manual_override_flag,invoice_description,invoice_source_code
99999,4000,900,9000,9999,999999,INV004,999,999,2022-01-01,0.00,Y,"",ORAFIN
1,4500,400,4001,1001,1,INV005,0,0,2025-12-31,99999999.99,N,"EdgeCase",ORAFIN
0,8999,700,5000,2000,0,INV006,1,1,2023-01-01,0.01,Y,"Edge,Comma",ORAFIN

## Error cases
invoice_distribution_id,natural_account_segment,gl_balancing_segment,cost_center_segment,gl_segment1,gl_code_combination_id,invoice_id,distribution_line_number,invoice_line_number,invoice_accounting_date,transaction_amount,xla_manual_override_flag,invoice_description,invoice_source_code
10001,3500,700,4001,1001,123456,INV001,1,1,2025-09-24,-100.00,N,"Negative Amount",ORAFIN
10002,8999,400,9000,9999,654321,INV002,2,1,2024-01-15,2500.00,Y,"Consulting Services",MAINFRAME
10003,4000,400,5000,2000,789012,INV003,1,2,2023-12-31,500.75,N,"Travel Expenses",Receivables

## NULL handling
invoice_distribution_id,natural_account_segment,gl_balancing_segment,cost_center_segment,gl_segment1,gl_code_combination_id,invoice_id,distribution_line_number,invoice_line_number,invoice_accounting_date,transaction_amount,xla_manual_override_flag,invoice_description,invoice_source_code
NULL,4500,700,4001,1001,123456,INV007,1,1,2025-09-24,1000.50,N,"Office Supplies",ORAFIN
10002,NULL,400,9000,9999,654321,INV008,2,1,2024-01-15,2500.00,Y,"Consulting Services",ORAFIN
10003,4000,NULL,5000,2000,789012,INV009,1,2,2023-12-31,500.75,N,"Travel Expenses",ORAFIN


### purgo_playground.dw_party_d
## Happy path
party_id,party_name,supplier_number
SP001,"Acme Corp",10000001
SP002,"Global Supplies",10000002
SP003,"Edge Solutions",10000003

## Edge cases
party_id,party_name,supplier_number
SP004,"",10000004
SP005,"VeryLongSupplierNameExceedingNormalLengthButValid",99999999
SP006,"Unicode测试",10000006

## Error cases
party_id,party_name,supplier_number
SP001,"Acme Corp",00032238
SP002,"Global Supplies",00080463
SP003,"Edge Solutions",90000147

## NULL handling
party_id,party_name,supplier_number
NULL,"Acme Corp",10000007
SP008,NULL,10000008
SP009,"Edge Solutions",NULL


### purgo_playground.dw_supplier_site_d
## Happy path
supplier_site_id,address1,address2,city,state,country,PAYMENT_TERMS_ID
SS001,"123 Main St","Suite 100","New York","NY","US",PT001
SS002,"456 Market Ave","Floor 2","San Francisco","CA","US",PT002
SS003,"789 Broadway","","Los Angeles","CA","US",PT003

## Edge cases
supplier_site_id,address1,address2,city,state,country,PAYMENT_TERMS_ID
SS004,"","Suite 200","Chicago","IL","US",PT004
SS005,"LongAddressFieldExceedingNormalLengthButValid","","Houston","TX","US",PT005
SS006,"Unicode地址","测试","Beijing","BJ","CN",PT006

## Error cases
supplier_site_id,address1,address2,city,state,country,PAYMENT_TERMS_ID
SS001,"123 Main St","Suite 100","New York","NY","US",NULL
SS002,"456 Market Ave","Floor 2","San Francisco","CA","US",""
SS003,"789 Broadway","","Los Angeles","CA","US","INVALID"

## NULL handling
supplier_site_id,address1,address2,city,state,country,PAYMENT_TERMS_ID
NULL,"123 Main St","Suite 100","New York","NY","US",PT007
SS008,NULL,"Floor 3","Miami","FL","US",PT008
SS009,"789 Broadway",NULL,"Los Angeles","CA","US",PT009


### purgo_playground.dw_internal_org_d_tl
## Happy path
organization_id,organization_name
100,"US Operations"
200,"EU Operations"
300,"Asia Operations"

## Edge cases
organization_id,organization_name
999,""
1,"VeryLongOrganizationNameExceedingNormalLengthButValid"
0,"Unicode组织"

## Error cases
organization_id,organization_name
100,NULL
200,""
NULL,"Asia Operations"

## NULL handling
organization_id,organization_name
NULL,"US Operations"
300,NULL
400,"NULL"


### purgo_playground.dw_ap_terms_d_tl
## Happy path
payment_terms_id,payment_term_name,payment_term_description
PT001,"Net 30","Payment due in 30 days"
PT002,"Net 45","Payment due in 45 days"
PT003,"Immediate","Payment due immediately"

## Edge cases
payment_terms_id,payment_term_name,payment_term_description
PT004,"",""
PT005,"Net 999","Payment due in 999 days"
PT006,"Unicode条款","测试描述"

## Error cases
payment_terms_id,payment_term_name,payment_term_description
PT001,NULL,"Payment due in 30 days"
PT002,"Net 45",NULL
PT003,"Immediate","INVALID"

## NULL handling
payment_terms_id,payment_term_name,payment_term_description
NULL,"Net 30","Payment due in 30 days"
PT008,NULL,"Payment due in 45 days"
PT009,"Immediate",NULL


### purgo_playground.dw_natural_account_d
## Happy path
natural_account_segment
4500
8999
4000

## Edge cases
natural_account_segment
4000
9999
0

## Error cases
natural_account_segment
3500
10000
NULL

## NULL handling
natural_account_segment
NULL
NULL
NULL


### purgo_playground.dw_ap_sla_payments_cf
## Happy path
invoice_id,invoice_distribution_id,check_date,check_void_date
INV001,10001,2025-09-30,1901-01-01T00:00:00.000+0000
INV002,10002,2024-01-20,1901-01-01T00:00:00.000+0000
INV003,10003,2023-12-31,1901-01-01T00:00:00.000+0000

## Edge cases
invoice_id,invoice_distribution_id,check_date,check_void_date
INV004,99999,2022-01-01,1901-01-01T00:00:00.000+0000
INV005,1,2025-12-31,1901-01-01T00:00:00.000+0000
INV006,0,2023-01-01,1901-01-01T00:00:00.000+0000

## Error cases
invoice_id,invoice_distribution_id,check_date,check_void_date
INV001,10001,2025-09-30,2025-09-30T00:00:00.000+0000
INV002,10002,2024-01-20,NULL
INV003,10003,2023-12-31,INVALID

## NULL handling
invoice_id,invoice_distribution_id,check_date,check_void_date
NULL,10001,2025-09-30,1901-01-01T00:00:00.000+0000
INV008,NULL,2024-01-20,1901-01-01T00:00:00.000+0000
INV009,10003,NULL,1901-01-01T00:00:00.000+0000


### purgo_playground.dw_gl_segment_d_tl
## Happy path
gl_segment_code,gl_segment_valueset_code,gl_segment_description
4001,"Center FS_CCG_COA","US Center"
700,"Bal Entity FS_CCG_COA","Corporate"
1001,"Sub Account FS_CCG_COA","SubAccount"

## Edge cases
gl_segment_code,gl_segment_valueset_code,gl_segment_description
9000,"Center FS_CCG_COA",""
400,"Bal Entity FS_CCG_COA","VeryLongDescriptionExceedingNormalLengthButValid"
9999,"Sub Account FS_CCG_COA","Unicode描述"

## Error cases
gl_segment_code,gl_segment_valueset_code,gl_segment_description
4001,"INVALID","US Center"
700,"Bal Entity FS_CCG_COA",NULL
NULL,"Sub Account FS_CCG_COA","SubAccount"

## NULL handling
gl_segment_code,gl_segment_valueset_code,gl_segment_description
NULL,"Center FS_CCG_COA","US Center"
1001,NULL,"SubAccount"
9999,"Sub Account FS_CCG_COA",NULL


### purgo_playground.dw_gl_code_combination_d
## Happy path
code_combination_id,concat_segments
123456,"4001.700.1001.0000.0000.0000.0000"
654321,"9000.400.9999.0000.0000.0000.0000"
789012,"5000.400.2000.0000.0000.0000.0000"

## Edge cases
code_combination_id,concat_segments
999999,"9000.900.9999.0000.0000.0000.0000"
1,"4001.400.1001.0000.0000.0000.0000"
0,"5000.700.2000.0000.0000.0000.0000"

## Error cases
code_combination_id,concat_segments
123456,"4009999110011000000000000000"
654321,"7009801138013800000000000000"
789012,"4009999172017211000000000000"

## NULL handling
code_combination_id,concat_segments
NULL,"4001.700.1001.0000.0000.0000.0000"
654321,NULL
789012,"NULL"


### purgo_edp_lkp.edp_lkup
## Happy path
lkup_key_01,lkup_key_02,lkup_key_03,lkup_key_04,lkup_typ_nm,lkup_val_01,lkup_val_03
usorafin,4001,5000,"1001-2000",TFS_CC_TO_DIV,"CCG Group","HFM001"
usorafin,700,9000,"9999-9999",TFS_COCD_CCNTR_GLACCT_TO_DIVCD,"Corporate","HFM002"
usorafin,400,4000,"4000-4000",PAYMENT_TERMS_MAPPING,"Net 30","HFM003"

## Edge cases
lkup_key_01,lkup_key_02,lkup_key_03,lkup_key_04,lkup_typ_nm,lkup_val_01,lkup_val_03
usorafin,9000,9999,"","TFS_CC_TO_DIV","",NULL
USORAFIN,400,9000,NULL,TFS_COCD_CCNTR_GLACCT_TO_DIVCD,"VeryLongDivisionNameExceedingNormalLengthButValid","HFM004"
usorafin,0,0,"0-0",PAYMENT_TERMS_MAPPING,"Unicode值","HFM005"

## Error cases
lkup_key_01,lkup_key_02,lkup_key_03,lkup_key_04,lkup_typ_nm,lkup_val_01,lkup_val_03
usorafin,4001,5000,"1001-2000",TFS_CC_TO_DIV,NULL,"HFM001"
usorafin,700,9000,"9999-9999",TFS_COCD_CCNTR_GLACCT_TO_DIVCD,"Corporate",NULL
usorafin,400,4000,"4000-4000",PAYMENT_TERMS_MAPPING,"INVALID","HFM003"

## NULL handling
lkup_key_01,lkup_key_02,lkup_key_03,lkup_key_04,lkup_typ_nm,lkup_val_01,lkup_val_03
NULL,4001,5000,"1001-2000",TFS_CC_TO_DIV,"CCG Group","HFM001"
usorafin,NULL,9000,"9999-9999",TFS_COCD_CCNTR_GLACCT_TO_DIVCD,"Corporate","HFM002"
usorafin,400,4000,NULL,PAYMENT_TERMS_MAPPING,"Net 30",NULL


### purgo_dims.dim_wf_company
## Happy path
co_cd,co_nm
400,"CCG Group"
700,"Corporate"
900,"International"

## Edge cases
co_cd,co_nm
999,""
1,"VeryLongCompanyNameExceedingNormalLengthButValid"
0,"Unicode公司"

## Error cases
co_cd,co_nm
400,NULL
700,""
NULL,"International"

## NULL handling
co_cd,co_nm
NULL,"CCG Group"
900,NULL
1000,"NULL"
