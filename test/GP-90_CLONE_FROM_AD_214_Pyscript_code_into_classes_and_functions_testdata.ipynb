# %%
# %csv
### purgo_playground.sales_kpi
## Test Data Categories
sales_year,sales_product_id,product_name,market_segment,total_sales,prev_year_sales,yoy_growth_pct,avg_market_share,market_penetration_flag,sales_rank
2023,PROD001,"Pain Relief","OTC",5000,4000,25.00,30.00,High,1
2023,PROD002,"Cough Syrup","OTC",4000,4000,0.00,25.00,Medium,2
2023,PROD003,"Antibiotic","Rx",3000,NULL,NULL,9.99,Low,3
2022,PROD001,"Pain Relief","OTC",4000,1000,300.00,10.00,Medium,1
2022,PROD004,"Vitamins","OTC",500,NULL,NULL,NULL,Low,2


### purgo_playground.product_marketshare_data
## Test Data Categories
ms_product_id,market_share_pct
PROD001,30.00
PROD002,25.00
PROD003,9.99
PROD004,NULL
"PROD005",""  # Error case: empty string for DOUBLE type


### purgo_playground.product_sales_data
## Test Data Categories
transaction_id,sales_product_id,sales_amount,sales_date
TXN001,PROD001,2500,2023-01-15
TXN002,PROD001,2500,2023-06-20
TXN003,PROD002,4000,2023-03-10
TXN004,PROD003,3000,2023-05-05
TXN005,PROD004,NULL,2022-07-12


### purgo_playground.product_data
## Test Data Categories
product_id,product_name,market_segment
PROD001,"Pain Relief","OTC"
PROD002,"Cough Syrup","OTC"
PROD003,"Antibiotic","Rx"
PROD004,"Vitamins","OTC"
NULL,"Unknown","Unknown"


### purgo_playground.sales_info
## Test Data Categories
Sale_ID,Product_ID,Batch_ID,Sale_Quantity,Sale_Date,Region,Sale_Price_Per_Unit
S001,PROD001,B001,100,2023-01-15,US,20
S002,PROD002,B002,200,2023-03-10,US,15
S003,PROD003,B003,150,2023-05-05,EU,25
S004,PROD004,B004,NULL,2022-07-12,EU,10
S005,PROD005,B005,50,NULL,ASIA,12


### purgo_playground.sales_data
## Test Data Categories
Sale_ID,Medicine_ID,Category,Continent,Revenue
S001,MED001,"Analgesic","North America",1000.50
S002,MED002,"Antibiotic","Europe",2000.00
S003,MED003,"Vitamin","Asia",NULL
S004,MED004,"Cough","Africa",500.00
S005,NULL,"Unknown","Unknown",1500.00


### purgo_playground.stg_us_sales
## Test Data Categories
Wholesaler_File_Name,Source_System_Name,Source_Product_ID,Source_Product_Description,Brand,Customer_ID,Customer_Name,Address_Line_1,City,State,Post_Code,Net_Sales,Gross_Sales,Packs,Units,Sales_Date,Volume,Country_Code,Bill_to_Customer_ID,Currency_Code,delivery_file_name
"file1.csv","SAP",1001,"Pain Relief 500mg","BrandA",12345,"PharmaCorp","123 Main St","New York","NY","10001",5000,5500.00,"10x50",500,"2023-01-15",1000,"US",12345,"USD","delivery1.csv"
"file2.csv","Oracle",1002,"Cough Syrup 250ml","BrandB",23456,"HealthPlus","456 Elm St","Los Angeles","CA","90001",4000,4200.00,"20x25",400,"2023-03-10",800,"US",23456,"USD","delivery2.csv"
"file3.csv","SAP",1003,"Antibiotic 250mg","BrandC",34567,"Medico","789 Oak St","Chicago","IL","60601",3000,3100.00,"15x20",300,"2023-05-05",600,"US",34567,"USD","delivery3.csv"
"file4.csv","Oracle",NULL,"Vitamins 100mg","BrandD",45678,"Wellness","321 Pine St","Houston","TX","77001",NULL,2000.00,"5x10",100,"2022-07-12",200,"US",45678,"USD","delivery4.csv"
"file5.csv","SAP",1005,"Unknown","BrandE",NULL,"Unknown","Unknown","Unknown","Unknown","00000",1000,1100.00,"1x50",50,"2023-09-01",100,"US",1005,"USD","delivery5.csv"


### purgo_playground.sales_data_excel
## Test Data Categories
Transaction_ID,Date,Product,Brand,Region,Distributor,Gross_Sales,Packs,Discount,Tax,Net_Sales,Volume
1001,2023-01-15T00:00:00.000+0000,"Pain Relief","BrandA","US","PharmaCorp",5000,100,50.00,100.00,4850.00,1000.00
1002,2023-03-10T00:00:00.000+0000,"Cough Syrup","BrandB","US","HealthPlus",4000,80,40.00,80.00,3880.00,800.00
1003,2023-05-05T00:00:00.000+0000,"Antibiotic","BrandC","EU","Medico",3000,60,30.00,60.00,2910.00,600.00
1004,NULL,"Vitamins","BrandD","EU","Wellness",2000,40,20.00,40.00,1940.00,400.00
1005,2023-09-01T00:00:00.000+0000,"Unknown","BrandE","ASIA","Unknown",1000,20,10.00,20.00,970.00,200.00


### purgo_playground.sales_data_transformed
## Test Data Categories
Sale_ID,Medicine_ID,Category,Continent,Revenue,Bonus_Eligibility,performance_flag,product_perf_band,rep_tier
S001,MED001,"Analgesic","North America",1000.50,"Yes","High","A","Tier1"
S002,MED002,"Antibiotic","Europe",2000.00,"No","Medium","B","Tier2"
S003,MED003,"Vitamin","Asia",NULL,"No","Low","C","Tier3"
S004,MED004,"Cough","Africa",500.00,"Yes","High","A","Tier1"
S005,NULL,"Unknown","Unknown",1500.00,"No","Low","C","Tier3"


### purgo_playground.sales_analysis_results
## Test Data Categories
Sales_ID,Product,Region,Year,Quarter,Sales_Amount,Rank,Previous_Quarter_Sales,Sales_Percentage_Change
1,"Pain Relief","US",2023,1,5000,1,NULL,NULL
2,"Cough Syrup","US",2023,1,4000,2,3500,14.29
3,"Antibiotic","EU",2023,2,3000,3,3000,0.00
4,"Vitamins","EU",2022,3,2000,1,NULL,NULL
5,"Unknown","ASIA",2023,4,NULL,NULL,NULL,NULL


### purgo_playground.market_data
## Test Data Categories
product_id,region,market_share
PROD001,"US",30.00
PROD002,"US",25.00
PROD003,"EU",9.99
PROD004,"EU",NULL
PROD005,"ASIA",15.00
