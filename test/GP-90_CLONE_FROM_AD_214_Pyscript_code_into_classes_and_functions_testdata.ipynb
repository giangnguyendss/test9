# %%
# %csv
### purgo_playground.product_data
## Test Data Categories
product_id,product_name,market_segment
P001,"Pain Relief, Extra Strength","OTC"
P002,"Allergy ""Fast"" Tabs","OTC"
P003,"CardioMax","Rx"
P004,"SleepWell","OTC"
P005,NULL,"Rx"


### purgo_playground.product_sales_data
## Test Data Categories
transaction_id,sales_product_id,sales_amount,sales_date
T001,P001,10000,2023-01-15
T002,P002,5000,2023-02-20
T003,P003,2000,2023-03-10
T004,P001,8000,2022-05-12
T005,P002,NULL,2022-06-18


### purgo_playground.product_marketshare_data
## Test Data Categories
ms_product_id,market_share_pct
P001,30.0
P002,15.0
P003,8.0
P001,30.0
P004,NULL


### purgo_playground.sales_kpi
## Test Data Categories
sales_year,sales_product_id,product_name,market_segment,total_sales,prev_year_sales,yoy_growth_pct,avg_market_share,market_penetration_flag,sales_rank
2023,P001,"Pain Relief, Extra Strength","OTC",10000,8000,25.0,30.0,High,1
2023,P002,"Allergy ""Fast"" Tabs","OTC",5000,5000,0.0,15.0,Medium,2
2023,P003,"CardioMax","Rx",2000,NULL,NULL,8.0,Low,3
2022,P001,"Pain Relief, Extra Strength","OTC",8000,NULL,NULL,30.0,High,1
2022,P002,"Allergy ""Fast"" Tabs","OTC",NULL,NULL,NULL,15.0,Medium,2
