# %%
# %csv
### purgo_playground.actual_file_rowskip3_stg
## Test Data Categories
value
"Alpha"
"Bravo"
"Charlie"
"Delta"
NULL


### purgo_playground.wrk_actual_file_rowskip3
## Test Data Categories
value
"TestValue1"
"TestValue2"
"Test,Value3"
NULL
"TestValue5"


### purgo_playground.data_map
## Test Data Categories
Source System Name,Source Table Name,Source Column Name,Source Datatype,Length,Target Table Name,Target Column Name,Target Datatype,Logic
"SystemA","TableA","ColA","STRING",255,"TableB","ColB","STRING","Direct Map"
"SystemB","TableB","ColB","BIGINT",10,"TableC","ColC","BIGINT","Cast to BIGINT"
"SystemC","TableC","ColC","STRING",NULL,"TableD","ColD","STRING","NULL if empty"
"SystemD","TableD","ColD","DECIMAL",18,"TableE","ColE","DECIMAL","Round to 2 decimals"
NULL,"TableE","ColE","STRING",100,"TableF","ColF","STRING","Default ''"


### purgo_playground.d_comp
## Test Data Categories
src_sys_cd,co_cd,co_nm,st_cd,st_nm,rgn_cd,rgn_nm,cntry_cd,cntry_nm,source_country,crt_dt
"SYS1","001","Company One","CA","California","W","West","US","United States","USA","2024-03-21T00:00:00.000+0000"
"SYS2","002","Company Two","NY","New York","E","East","US","United States","USA","2024-06-15T12:30:45.000+0000"
"SYS3","003","Company Three",NULL,NULL,"S","South","MX","Mexico","Mexico","2025-01-01T08:00:00.000+0000"
"SYS4","004","Company Four","TX","Texas",NULL,NULL,"US","United States",NULL,"2023-12-31T23:59:59.000+0000"
NULL,"005","Company Five","FL","Florida","SE","Southeast","US","United States","USA",NULL


### purgo_playground.wrk_actual_file
## Test Data Categories
value
"Row1"
"Row2"
"Row3"
"Row4"
NULL


### purgo_playground.raw_abc1234_1
## Test Data Categories
Clinical_Study_Source_Id,Study_Country_source_id,Study_Site_source_id,site_number,site_status,primary_investigator_source_id
"CSID001","SCID001","SSID001",1001,"Active","PIID001"
"CSID002","SCID002","SSID002",1002,"Inactive",NULL
"CSID003","SCID003","SSID003",1003,"Active","PIID003"
"CSID004","SCID004","SSID004",1004,NULL,"PIID004"
"CSID005","SCID005","SSID005",1005,"Active","PIID005"


### purgo_playground.pre_t1_master_clone1
## Test Data Categories
region,country_cd,src_sys,src_layer,f_format,job_id,pre_t1_query,view_name,description,stg_table,pre_t1_table,sequence,active_flag
"APAC","IN","SYS1","L1","CSV","JOB001","SELECT * FROM t1","vw_t1","Test query","stg_t1","pre_t1",1,"Y"
"EMEA","FR","SYS2","L2","PARQUET","JOB002","SELECT * FROM t2","vw_t2","Another test","stg_t2","pre_t2",2,"N"
"AMER","US","SYS3","L3","DELTA","JOB003","SELECT * FROM t3","vw_t3","Edge case","stg_t3","pre_t3",NULL,"Y"
NULL,"GB","SYS4","L4","CSV","JOB004","SELECT * FROM t4","vw_t4","NULL region","stg_t4","pre_t4",4,"N"
"APAC",NULL,"SYS5","L5","PARQUET","JOB005","SELECT * FROM t5","vw_t5","NULL country","stg_t5","pre_t5",5,NULL


### purgo_playground.pre_t1_master_clone
## Test Data Categories
region,country_cd,src_sys,src_layer,f_format,job_id,pre_t1_query,view_name,description,stg_table,pre_t1_table,sequence,active_flag
"EU","DE","SYS1","L1","CSV","JOB101","SELECT * FROM t101","vw_t101","Clone test","stg_t101","pre_t101",101,"Y"
"NA","US","SYS2","L2","PARQUET","JOB102","SELECT * FROM t102","vw_t102","Another clone","stg_t102","pre_t102",102,"N"
"APAC","JP","SYS3","L3","DELTA","JOB103","SELECT * FROM t103","vw_t103","Edge clone","stg_t103","pre_t103",NULL,"Y"
NULL,"CN","SYS4","L4","CSV","JOB104","SELECT * FROM t104","vw_t104","NULL region","stg_t104","pre_t104",104,"N"
"EU",NULL,"SYS5","L5","PARQUET","JOB105","SELECT * FROM t105","vw_t105","NULL country","stg_t105","pre_t105",105,NULL


### purgo_playground.pre_t1_master
## Test Data Categories
region,country_cd,src_sys,src_layer,f_format,job_id,pre_t1_query,view_name,description,stg_table,pre_t1_table,sequence,active_flag
"LATAM","BR","SYS1","L1","CSV","JOB201","SELECT * FROM t201","vw_t201","Master test","stg_t201","pre_t201",201,"Y"
"EMEA","ZA","SYS2","L2","PARQUET","JOB202","SELECT * FROM t202","vw_t202","Another master","stg_t202","pre_t202",202,"N"
"APAC","SG","SYS3","L3","DELTA","JOB203","SELECT * FROM t203","vw_t203","Edge master","stg_t203","pre_t203",NULL,"Y"
NULL,"AU","SYS4","L4","CSV","JOB204","SELECT * FROM t204","vw_t204","NULL region","stg_t204","pre_t204",204,"N"
"LATAM",NULL,"SYS5","L5","PARQUET","JOB205","SELECT * FROM t205","vw_t205","NULL country","stg_t205","pre_t205",205,NULL


### purgo_playground.actual_file_stg
## Test Data Categories
value
"First"
"Second"
"Third"
"Fourth"
NULL
