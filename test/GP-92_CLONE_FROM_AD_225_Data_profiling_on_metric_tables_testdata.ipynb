# %%
# %csv
### purgo_databricks.purgo_playground.metric_profile
## Test Data Categories
column_name,data_type,distinct_count,max_value,mean,min_value,null_count,table_name,total_count
Claim_ID,string,1000,Z9999,NULL,A0001,0,health_insurance_claims_metric,1000
Age,bigint,60,99,45.2,18,10,health_insurance_claims_metric,1000
Service_Date,date,365,2023-12-31,NULL,2023-01-01,0,health_insurance_claims_metric,1000
is_fraud,boolean,2,1,0.03,0,0,health_insurance_claims_metric,1000
Gender,string,2,Male,NULL,Female,0,health_insurance_claims_metric,1000


### purgo_databricks.purgo_playground.metric_profile
## Test Data Categories
column_name,data_type,distinct_count,max_value,mean,min_value,null_count,table_name,total_count
product_id,bigint,100,100,50.5,1,0,d_product_revenue_metric,500
product_name,string,100,Zulu,NULL,Alpha,0,d_product_revenue_metric,500
first_purchase_date,date,365,2022-12-31,NULL,2022-01-01,5,d_product_revenue_metric,500
customer_first_revenue,double,200,1000.0,250.5,10.0,20,d_product_revenue_metric,500
is_returned,bigint,2,1,0.05,0,0,d_product_revenue_metric,500


### purgo_databricks.purgo_playground.metric_profile
## Test Data Categories
column_name,data_type,distinct_count,max_value,mean,min_value,null_count,table_name,total_count
pt_cdl_uuid,string,100,0100,NULL,0001,0,s_field_reporting_sales_source_customer_metric,100
evenity_unit_hash,int,8,8,4.5,1,0,s_field_reporting_sales_source_customer_metric,100
market_name,string,10,West,NULL,East,0,s_field_reporting_sales_source_customer_metric,100
cdl_frequency,int,5,5,3.0,1,2,s_field_reporting_sales_source_customer_metric,100
product_name,string,20,ProductZ,NULL,ProductA,1,s_field_reporting_sales_source_customer_metric,100
