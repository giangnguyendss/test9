# %%
# %csv
### purgo_playground.ods_free_drug_clone
## Test Data Categories
PM_ID,Shipment_Date,Dispense_ID,DELETE_FLAG,Drug_Name,Quantity,Patient_ID
"PM123","2024-03-21",1001,"Y","DrugA",30,"PAT001"
"PM124","2024-03-22",1002,"N","DrugB",0,"PAT002"
"PM125","2024-03-23",9223372036854775807,"Y","DrugC",1,"PAT003"
"PM126","2024-03-24",1004,"D","DrugD",999999999,"PAT004"
"PM127","2024-03-25",1005,"X","DrugE",NULL,"PAT005"


### purgo_playground.ods_non_contracting_clone
## Test Data Categories
PM_ID,Shipment_Date,Dispense_ID,DELETE_FLAG,Facility,Units_Provided,Contract_Flag
"PM201","2024-04-01",2001,"Y","FacilityA",10,"C"
"PM202","2024-04-02",2002,"N","FacilityB",0,"NC"
"PM203","2024-04-03",9223372036854775807,"Y","FacilityC",1,"C"
"PM204","2024-04-04",2004,"D","FacilityD",999999999,"NC"
"PM205","2024-04-05",2005,"X","FacilityE",NULL,"C"


### purgo_playground.ods_copay_clone
## Test Data Categories
PM_ID,NDC,Date_of_Service,Rx_Claim_Number,DELETE_FLAG,Copay_Amount,Plan_ID
"PM301","NDC001","2024-05-01","RX1001","Y",50,"PLAN01"
"PM302","NDC002","2024-05-02","RX1002","N",0,"PLAN02"
"PM303","NDC003","2024-05-03","RX1003","Y",1,"PLAN03"
"PM304","NDC004","2024-05-04","RX1004","D",999999999,"PLAN04"
"PM305","NDC005","2024-05-05","RX1005","X",NULL,"PLAN05"
