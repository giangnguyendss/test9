# %%
# %csv
### purgo_playground.patient_data
## Test Data Categories
patient_id,patient_name,age,diagnosis,treatment,ingestion_date,source_system,record_status,created_by,modified_by
1001,John Smith,45,Diabetes,Insulin,2024-06-01T10:00:00.000+0000,EMR,active,admin,admin
1002,Jane Doe,30,Asthma,Inhaler,2024-06-02T11:00:00.000+0000,Portal,pending,nurse,nurse
1003,Bob Lee,60,Cancer,Chemo,NULL,EMR,inactive,doctor,doctor
1004,Alice Kim,50,Hypertension,Beta Blocker,2024-06-03T09:30:00.000+0000,NULL,active,admin,nurse
1005,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL,NULL


### purgo_playground.patient_account_change_audit
## Test Data Categories
field_updated,operation,old_value,new_value,updated_date_time,hash_key,updated_month
diagnosis,UPDATE,Asthma,Diabetes,2024-06-01T10:05:00.000+0000,abc123,2024-06
treatment,INSERT,NULL,Insulin,2024-06-01T10:10:00.000+0000,def456,2024-06
record_status,UPDATE,active,inactive,2024-06-02T11:15:00.000+0000,ghi789,2024-06
source_system,UPDATE,Portal,EMR,2024-06-03T09:35:00.000+0000,jkl012,2024-06
NULL,DELETE,Chemo,NULL,NULL,NULL,NULL


### purgo_playground.patient_hist
## Test Data Categories
patient_sf_id,updated_column,updated_value,created_date
1001,diagnosis,Diabetes,2024-06-01
1002,treatment,Inhaler,2024-06-02
1003,record_status,inactive,2024-06-03
1004,source_system,EMR,2024-06-04
NULL,NULL,NULL,NULL


### purgo_playground.patient_notified_stg
## Test Data Categories
patient_id,prescriber_id,pf_shipment,is_notified,notification_date,IST_last_modified_date,key
1001,2001,SHIP123,true,2024-06-01,2024-06-01T10:00:00.000+0000,KEY001
1002,2002,SHIP124,false,2024-06-02,2024-06-02T11:00:00.000+0000,KEY002
1003,2003,SHIP125,true,2024-06-03,NULL,KEY003
1004,2004,NULL,false,NULL,NULL,KEY004
NULL,NULL,NULL,NULL,NULL,NULL,NULL


### purgo_playground.patient_notified
## Test Data Categories
patient_id,prescriber_id,pf_shipment,is_notified,notification_date,IST_last_modified_date,key
1001,2001,SHIP123,true,2024-06-01,2024-06-01T10:00:00.000+0000,KEY001
1002,2002,SHIP124,false,2024-06-02,2024-06-02T11:00:00.000+0000,KEY002
1003,2003,SHIP125,true,2024-06-03,NULL,KEY003
1004,2004,NULL,false,NULL,NULL,KEY004
NULL,NULL,NULL,NULL,NULL,NULL,NULL


### purgo_playground.wrk_patient_hist
## Test Data Categories
patient_sf_id,updated_column,updated_value,created_date
1001,diagnosis,Diabetes,2024-06-01
1002,treatment,Inhaler,2024-06-02
1003,record_status,inactive,2024-06-03
1004,source_system,EMR,2024-06-04
NULL,NULL,NULL,NULL


### purgo_playground.wrk_patient_notified
## Test Data Categories
patient_id,prescriber_id,pf_shipment,is_notified,notification_date,IST_last_modified_date,key
1001,2001,SHIP123,true,2024-06-01,2024-06-01T10:00:00.000+0000,KEY001
1002,2002,SHIP124,false,2024-06-02,2024-06-02T11:00:00.000+0000,KEY002
1003,2003,SHIP125,true,2024-06-03,NULL,KEY003
1004,2004,NULL,false,NULL,NULL,KEY004
NULL,NULL,NULL,NULL,NULL,NULL,NULL


### purgo_playground.patient_reg
## Test Data Categories
Source System Name,Table Name,Column Name,Datatype,Length,Logic
EMR,patient_data,patient_id,bigint,20,"Primary key"
Portal,patient_data,diagnosis,string,255,"Diagnosis from UI"
EMR,patient_data,ingestion_date,timestamp,NULL,"File upload timestamp"
Portal,patient_data,record_status,string,20,"Status validation"
NULL,NULL,NULL,NULL,NULL,NULL


### purgo_playground.audit_log
## Test Data Categories
timestamp,stage,status,message
2024-06-01T10:00:00.000+0000,ingest,success,"File uploaded successfully"
2024-06-02T11:00:00.000+0000,validate,error,"Invalid record_status value"
2024-06-03T09:30:00.000+0000,ingest,success,"Patient record ingested"
2024-06-04T08:00:00.000+0000,validate,warning,"Missing source_system"
NULL,NULL,NULL,NULL


### purgo_playground.stg_us_audit_log
## Test Data Categories
ChangeTime,Attribute,OldValue,NewValue
2024-06-01T10:00:00.000+0000,diagnosis,Asthma,Diabetes
2024-06-02T11:00:00.000+0000,treatment,NULL,Insulin
2024-06-03T09:30:00.000+0000,record_status,active,inactive
2024-06-04T08:00:00.000+0000,source_system,Portal,EMR
NULL,NULL,NULL,NULL
